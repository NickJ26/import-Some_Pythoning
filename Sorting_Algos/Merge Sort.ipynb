# %% [markdown]
# ## Merge Sort
#
# Merge Sort is a Divide and Conquer algorithm. It divides input array in two halves, calls itself for the two halves and then merges the two sorted halves.

# %%
from IPython.display import Image
Image (filename= r"File_Path\Merge_sort_algorithm_diagram.png")

# %%
def mergeSort(arr): 
    if len(arr)>1: 
        mid = len(arr)//2 #Finding the mid of the array 
        # Dividing the array elements into 2 halves  
        L = arr[:mid] #Left half 
        R = arr[mid:] #Right Half  
  
        mergeSort(L) # Sorting the first half 
        mergeSort(R) # Sorting the second half 
  
        i = j = k = 0
          
        # Copy data to temp arrays L[] and R[] 
        while i < len(L) and j < len(R): 
            if L[i] < R[j]: 
                arr[k] = L[i] 
                i+=1
            else: 
                arr[k] = R[j] 
                j+=1
            k+=1
          
        # Checking if any element was left 
        while i < len(L): 
            arr[k] = L[i] 
            i+=1
            k+=1
          
        while j < len(R): 
            arr[k] = R[j] 
            j+=1
            k+=1

arr = [38, 27, 43, 3, 9, 82, 10] #Change the Values in this list, if you want
print ("Given array is: ",arr)  
 
mergeSort(arr) 
print("Sorted array is:",arr)
# Out:
# Given array is:  [38, 27, 43, 3, 9, 82, 10]
# Sorted array is: [3, 9, 10, 27, 38, 43, 82]
